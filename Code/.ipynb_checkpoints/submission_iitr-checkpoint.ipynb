# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, f1_score
from scipy.ndimage.filters import gaussian_filter1d, uniform_filter1d, median_filter
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.set_style("darkgrid")

#Import libraries for Deep Learning
from keras.models import Sequential, Model
from keras.layers import Conv1D, LSTM, MaxPool1D, Dense, Dropout, Flatten, BatchNormalization, Input, concatenate, Activation
from keras.optimizers import Adam

print ('Libraries Loaded!')
# Out:
# Using TensorFlow backend.
# Libraries Loaded!

# %%
#Created a function to remove noise from data with fourier transformation

def fourier(data):
    datafft= np.zeros(data.shape)
    for row in range(data.shape[0]):
        #fft
        fou=np.fft.fft(data[row])
        f1,f2= 0, 0
        fr=np.fft.fftfreq(3197,0.01)
        #make up a narrow bandpass with a Gaussian
        df=0.1
        gpl= np.exp(- ((fr-f1)/(2*df))**2)+ np.exp(- ((fr-f2)/(2*df))**2)  # pos. frequencies
        gmn= np.exp(- ((fr+f1)/(2*df))**2)+ np.exp(- ((fr+f2)/(2*df))**2)  # neg. frequencies
        g=gpl+gmn    
        filt=fou*g  #filtered spectrum = spectrum * bandpass 
        #ifft
        s2=np.fft.ifft(filt)
        datafft[row]= s2
    return (datafft)

# %%
data1 = pd.read_csv('ExoTrain.csv')
Y1 = data1['LABEL'].values - 1
x_train = data1.drop('LABEL', axis=1).values
y_train = Y1[:,np.newaxis]

# %%
data1 = pd.read_csv('Final Test.csv')
Y1 = data1['LABEL'].values - 1
x_final = data1.drop('LABEL', axis=1).values
y_final = Y1[:,np.newaxis]

# %%
x_train = ((x_train - np.mean(x_train, axis=1).reshape(-1,1)) / 
           np.std(x_train, axis=1).reshape(-1,1))
x_final = ((x_final - np.mean(x_final, axis=1).reshape(-1,1)) / 
          np.std(x_final, axis=1).reshape(-1,1))

# %%
x_train1 = np.stack([x_train, gaussian_filter1d(x_train, 1, axis=1)], axis=2)
x_final1 = np.stack([x_final, gaussian_filter1d(x_final, 1, axis=1)], axis=2)

# %%
x_train2 = np.stack([x_train, fourier(x_train)], axis=2)
x_final2 = np.stack([x_final, fourier(x_final)], axis=2)

# %%
x_train3 = x_train[:,:,np.newaxis]
x_final3 = x_final[:,:,np.newaxis]

# %%
print ('Shape of x_train1', x_train1.shape)
print ('Shape of x_final1', x_final1.shape)
print("*"*40)
print ('Shape of x_train2', x_train2.shape)
print ('Shape of x_final2', x_final2.shape)
print("*"*40)
print ('Shape of x_train3', x_train3.shape)
print ('Shape of x_final3', x_final3.shape)
# Out:
# Shape of x_train1 (3960, 3197, 2)
# Shape of x_final1 (2000, 3197, 2)
# ****************************************
# Shape of x_train2 (3960, 3197, 2)
# Shape of x_final2 (2000, 3197, 2)
# ****************************************
# Shape of x_train3 (3960, 3197, 1)
# Shape of x_final3 (2000, 3197, 1)

# %%
# 1-D convolutions are frequently used to learn sequential patterns
model1 = Sequential()
model1.add(Conv1D(filters=16, kernel_size=11, activation='relu', input_shape=x_train1.shape[1:]))
model1.add(MaxPool1D(strides=4))
model1.add(BatchNormalization())
model1.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
model1.add(MaxPool1D(strides=4))
model1.add(BatchNormalization())
model1.add(Conv1D(filters=32, kernel_size=11, activation='relu'))
model1.add(MaxPool1D(strides=4))
model1.add(BatchNormalization())
model1.add(Conv1D(filters=32, kernel_size=11, activation='relu'))
model1.add(MaxPool1D(strides=4))
model1.add(Flatten())
model1.add(Dropout(0.3))
model1.add(Dense(32, activation='relu'))
model1.add(Dropout(0.3))
model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.3))
model1.add(Dense(1, activation='sigmoid'))

# %%
# 1-D convolutions are frequently used to learn sequential patterns
model3 = Sequential()
model3.add(Conv1D(filters=16, kernel_size=11, activation='selu', input_shape=x_train3.shape[1:]))
model3.add(MaxPool1D(strides=4))
model3.add(BatchNormalization())
model3.add(Conv1D(filters=64, kernel_size=11, activation='selu'))
model3.add(MaxPool1D(strides=4))
model3.add(BatchNormalization())
model3.add(Conv1D(filters=32, kernel_size=11, activation='selu'))
model3.add(MaxPool1D(strides=4))
model3.add(BatchNormalization())
model3.add(Conv1D(filters=32, kernel_size=11, activation='selu'))
model3.add(MaxPool1D(strides=4))
model3.add(LSTM(10))
model3.add(Dense(1, activation='sigmoid'))

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 3187, 16)          368
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 797, 16)           0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 797, 16)           64
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 787, 64)           11328
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 197, 64)           0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 197, 64)           256
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 187, 32)           22560
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 47, 32)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 47, 32)            128
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 37, 32)            11296
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 9, 32)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 288)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                9248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 57,425
# Trainable params: 57,201
# Non-trainable params: 224
# _________________________________________________________________

# %%
model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 3187, 16)          192
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 797, 16)           0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 797, 16)           64
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 787, 64)           11328
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 197, 64)           0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 197, 64)           256
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 187, 32)           22560
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 47, 32)            0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 47, 32)            128
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 37, 32)            11296
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 9, 32)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10)                1720
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 47,555
# Trainable params: 47,331
# Non-trainable params: 224
# _________________________________________________________________

# %%
# feeding training data to the model in batches
def batch_generator(x_train, y_train, batch_size=32):
    """
    Gives equal number of positive and negative samples, and rotates them randomly in time
    """
    half_batch = 16
    x_batch = np.empty((batch_size, x_train.shape[1], x_train.shape[2]), dtype='float32')
    y_batch = np.empty((batch_size, y_train.shape[1]), dtype='float32')
    
    planet = np.where(y_train[:,0] == 1.)[0]
    non_planet = np.where(y_train[:,0] == 0.)[0]
    
    while True:
        np.random.shuffle(planet)
        np.random.shuffle(non_planet)
    
        x_batch[:half_batch] = x_train[planet[:half_batch]]
        x_batch[half_batch:] = x_train[non_planet[half_batch:batch_size]]
        y_batch[:half_batch] = y_train[planet[:half_batch]]
        y_batch[half_batch:] = y_train[non_planet[half_batch:batch_size]]
    
        for i in range(batch_size):
            roll_state = np.random.randint(x_batch.shape[1])
            x_batch[i] = np.roll(x_batch[i], roll_state, axis = 0)
     
        yield x_batch, y_batch

# %%
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model1_history = model1.fit_generator(batch_generator(x_train1, y_train, 48),
                    verbose=2, epochs=35,
                    steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/35
# 1s - loss: 0.5643 - acc: 0.6904
# Epoch 2/35
# 0s - loss: 0.3405 - acc: 0.8424
# Epoch 3/35
# 0s - loss: 0.1894 - acc: 0.9223
# Epoch 4/35
# 0s - loss: 0.0931 - acc: 0.9705
# Epoch 5/35
# 0s - loss: 0.0695 - acc: 0.9766
# Epoch 6/35
# 0s - loss: 0.0623 - acc: 0.9809
# Epoch 7/35
# 0s - loss: 0.0826 - acc: 0.9752
# Epoch 8/35
# 0s - loss: 0.0425 - acc: 0.9863
# Epoch 9/35
# 0s - loss: 0.0415 - acc: 0.9880
# Epoch 10/35
# 0s - loss: 0.0485 - acc: 0.9855
# Epoch 11/35
# 0s - loss: 0.0350 - acc: 0.9891
# Epoch 12/35
# 0s - loss: 0.0335 - acc: 0.9912
# Epoch 13/35
# 0s - loss: 0.0173 - acc: 0.9943
# Epoch 14/35
# 0s - loss: 0.0326 - acc: 0.9916
# Epoch 15/35
# 0s - loss: 0.0264 - acc: 0.9931
# Epoch 16/35
# 0s - loss: 0.0357 - acc: 0.9899
# Epoch 17/35
# 0s - loss: 0.0292 - acc: 0.9899
# Epoch 18/35
# 0s - loss: 0.0256 - acc: 0.9933
# Epoch 19/35
# 0s - loss: 0.0303 - acc: 0.9891
# Epoch 20/35
# 0s - loss: 0.0229 - acc: 0.9928
# Epoch 21/35
# 0s - loss: 0.0286 - acc: 0.9912
# Epoch 22/35
# 0s - loss: 0.0274 - acc: 0.9935
# Epoch 23/35
# 0s - loss: 0.0310 - acc: 0.9928
# Epoch 24/35
# 0s - loss: 0.0233 - acc: 0.9920
# Epoch 25/35
# 0s - loss: 0.0161 - acc: 0.9954
# Epoch 26/35
# 0s - loss: 0.0141 - acc: 0.9952
# Epoch 27/35
# 0s - loss: 0.0120 - acc: 0.9962
# Epoch 28/35
# 0s - loss: 0.0226 - acc: 0.9931
# Epoch 29/35
# 0s - loss: 0.0190 - acc: 0.9943
# Epoch 30/35
# 0s - loss: 0.0268 - acc: 0.9907
# Epoch 31/35
# 0s - loss: 0.0128 - acc: 0.9977
# Epoch 32/35
# 0s - loss: 0.0159 - acc: 0.9949
# Epoch 33/35
# 0s - loss: 0.0189 - acc: 0.9947
# Epoch 34/35
# 0s - loss: 0.0226 - acc: 0.9931
# Epoch 35/35
# 0s - loss: 0.0186 - acc: 0.9954

# %%
model1.compile(optimizer=Adam(0.0001), loss = 'binary_crossentropy', metrics=['accuracy'])
model1_history2 = model1.fit_generator(batch_generator(x_train1, y_train, 48),
                           verbose=2, epochs=5,
                           steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/5
# 0s - loss: 0.0069 - acc: 0.9979
# Epoch 2/5
# 0s - loss: 0.0063 - acc: 0.9981
# Epoch 3/5
# 0s - loss: 0.0078 - acc: 0.9975
# Epoch 4/5
# 0s - loss: 0.0068 - acc: 0.9979
# Epoch 5/5
# 0s - loss: 0.0060 - acc: 0.9983

# %%
model1.compile(optimizer=Adam(0.00001), loss = 'binary_crossentropy', metrics=['accuracy'])
model1_history3 = model1.fit_generator(batch_generator(x_train1, y_train, 48),
                    verbose=2, epochs=5,
                    steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/5
# 0s - loss: 0.0033 - acc: 0.9992
# Epoch 2/5
# 0s - loss: 0.0049 - acc: 0.9989
# Epoch 3/5
# 0s - loss: 0.0066 - acc: 0.9983
# Epoch 4/5
# 0s - loss: 0.0032 - acc: 0.9989
# Epoch 5/5
# 0s - loss: 0.0027 - acc: 0.9989

# %%
# 1-D convolutions are frequently used to learn sequential patterns
model2 = Sequential()
model2.add(Conv1D(filters=24, kernel_size=11, activation='relu', input_shape=x_train2.shape[1:]))
model2.add(MaxPool1D(strides=4))
model2.add(BatchNormalization())
model2.add(Conv1D(filters=64, kernel_size=7, activation='relu'))
model2.add(MaxPool1D(strides=4))
model2.add(BatchNormalization())
model2.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
model2.add(MaxPool1D(strides=4))
model2.add(BatchNormalization())
model2.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
model2.add(MaxPool1D(strides=4))
model2.add(Flatten())
model2.add(Dropout(0.3))
model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(64, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

# %%
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 3187, 24)          552
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 797, 24)           0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 797, 24)           96
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 791, 64)           10816
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 198, 64)           0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 198, 64)           256
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 188, 64)           45120
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 47, 64)            0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 47, 64)            256
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 37, 64)            45120
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 9, 64)             0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 576)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                18464
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 122,857
# Trainable params: 122,553
# Non-trainable params: 304
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model2_history = model2.fit_generator(batch_generator(x_train2, y_train, 48),
                    verbose=2, epochs=35,
                    steps_per_epoch=x_train.shape[1]//48)
# Out:
# Epoch 1/35
# 1s - loss: 0.5207 - acc: 0.7396
# Epoch 2/35
# 0s - loss: 0.3966 - acc: 0.8033
# Epoch 3/35
# 0s - loss: 0.3131 - acc: 0.8545
# Epoch 4/35
# 0s - loss: 0.2629 - acc: 0.8908
# Epoch 5/35
# 0s - loss: 0.2035 - acc: 0.9145
# Epoch 6/35
# 0s - loss: 0.1517 - acc: 0.9410
# Epoch 7/35
# 0s - loss: 0.1336 - acc: 0.9533
# Epoch 8/35
# 0s - loss: 0.0833 - acc: 0.9675
# Epoch 9/35
# 0s - loss: 0.0728 - acc: 0.9738
# Epoch 10/35
# 0s - loss: 0.0386 - acc: 0.9877
# Epoch 11/35
# 0s - loss: 0.0601 - acc: 0.9789
# Epoch 12/35
# 0s - loss: 0.0471 - acc: 0.9852
# Epoch 13/35
# 0s - loss: 0.0298 - acc: 0.9912
# Epoch 14/35
# 0s - loss: 0.0303 - acc: 0.9893
# Epoch 15/35
# 0s - loss: 0.0317 - acc: 0.9902
# Epoch 16/35
# 0s - loss: 0.0252 - acc: 0.9924
# Epoch 17/35
# 0s - loss: 0.0287 - acc: 0.9921
# Epoch 18/35
# 0s - loss: 0.0172 - acc: 0.9953
# Epoch 19/35
# 0s - loss: 0.0201 - acc: 0.9962
# Epoch 20/35
# 0s - loss: 0.0139 - acc: 0.9978
# Epoch 21/35
# 0s - loss: 0.0178 - acc: 0.9959
# Epoch 22/35
# 0s - loss: 0.0426 - acc: 0.9871
# Epoch 23/35
# 0s - loss: 0.0290 - acc: 0.9927
# Epoch 24/35
# 0s - loss: 0.0175 - acc: 0.9940
# Epoch 25/35
# 0s - loss: 0.0120 - acc: 0.9962
# Epoch 26/35
# 0s - loss: 0.0290 - acc: 0.9931
# Epoch 27/35
# 0s - loss: 0.0232 - acc: 0.9924
# Epoch 28/35
# 0s - loss: 0.0185 - acc: 0.9940
# Epoch 29/35
# 0s - loss: 0.0260 - acc: 0.9921
# Epoch 30/35
# 0s - loss: 0.0120 - acc: 0.9956
# Epoch 31/35
# 0s - loss: 0.0342 - acc: 0.9905
# Epoch 32/35
# 0s - loss: 0.0339 - acc: 0.9896
# Epoch 33/35
# 0s - loss: 0.0142 - acc: 0.9953
# Epoch 34/35
# 0s - loss: 0.0059 - acc: 0.9981
# Epoch 35/35
# 0s - loss: 0.0190 - acc: 0.9931

# %%
model2.compile(optimizer=Adam(0.0001), loss = 'binary_crossentropy', metrics=['accuracy'])
model2_history2 = model2.fit_generator(batch_generator(x_train2, y_train, 48),
                           verbose=2, epochs=5,
                           steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/5
# 1s - loss: 0.0095 - acc: 0.9981
# Epoch 2/5
# 0s - loss: 0.0103 - acc: 0.9973
# Epoch 3/5
# 0s - loss: 0.0040 - acc: 0.9992
# Epoch 4/5
# 0s - loss: 0.0102 - acc: 0.9975
# Epoch 5/5
# 0s - loss: 0.0054 - acc: 0.9987

# %%
model2.compile(optimizer=Adam(0.00001), loss = 'binary_crossentropy', metrics=['accuracy'])
model2_history3 = model2.fit_generator(batch_generator(x_train2, y_train, 48),
                    verbose=2, epochs=5,
                    steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/5
# 1s - loss: 0.0020 - acc: 0.9994
# Epoch 2/5
# 0s - loss: 0.0035 - acc: 0.9989
# Epoch 3/5
# 0s - loss: 0.0063 - acc: 0.9985
# Epoch 4/5
# 0s - loss: 0.0028 - acc: 0.9989
# Epoch 5/5
# 0s - loss: 0.0032 - acc: 0.9987

# %%
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model3_history = model3.fit_generator(batch_generator(x_train3, y_train, 48),
                    verbose=2, epochs=35,
                    steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/35
# 1s - loss: 0.0802 - acc: 0.9739
# Epoch 2/35
# 1s - loss: 0.0560 - acc: 0.9834
# Epoch 3/35
# 1s - loss: 0.0636 - acc: 0.9792
# Epoch 4/35
# 1s - loss: 0.0472 - acc: 0.9842
# Epoch 5/35
# 1s - loss: 0.0312 - acc: 0.9905
# Epoch 6/35
# 1s - loss: 0.0327 - acc: 0.9895
# Epoch 7/35
# 1s - loss: 0.0255 - acc: 0.9910
# Epoch 8/35
# 1s - loss: 0.0354 - acc: 0.9895
# Epoch 9/35
# 1s - loss: 0.0265 - acc: 0.9924
# Epoch 10/35
# 1s - loss: 0.0198 - acc: 0.9931
# Epoch 11/35
# 1s - loss: 0.0179 - acc: 0.9952
# Epoch 12/35
# 1s - loss: 0.0299 - acc: 0.9907
# Epoch 13/35
# 1s - loss: 0.0286 - acc: 0.9912
# Epoch 14/35
# 1s - loss: 0.0239 - acc: 0.9922
# Epoch 15/35
# 1s - loss: 0.0223 - acc: 0.9931
# Epoch 16/35
# 1s - loss: 0.0219 - acc: 0.9939
# Epoch 17/35
# 1s - loss: 0.0170 - acc: 0.9958
# Epoch 18/35
# 1s - loss: 0.0174 - acc: 0.9949
# Epoch 19/35
# 1s - loss: 0.0108 - acc: 0.9964
# Epoch 20/35
# 1s - loss: 0.0085 - acc: 0.9977
# Epoch 21/35
# 1s - loss: 0.0161 - acc: 0.9956
# Epoch 22/35
# 1s - loss: 0.0120 - acc: 0.9966
# Epoch 23/35
# 1s - loss: 0.0176 - acc: 0.9945
# Epoch 24/35
# 1s - loss: 0.0186 - acc: 0.9949
# Epoch 25/35
# 1s - loss: 0.0149 - acc: 0.9945
# Epoch 26/35
# 1s - loss: 0.0099 - acc: 0.9971
# Epoch 27/35
# 1s - loss: 0.0084 - acc: 0.9981
# Epoch 28/35
# 1s - loss: 0.0126 - acc: 0.9954
# Epoch 29/35
# 1s - loss: 0.0084 - acc: 0.9979
# Epoch 30/35
# 1s - loss: 0.0110 - acc: 0.9975
# Epoch 31/35
# 1s - loss: 0.0085 - acc: 0.9981
# Epoch 32/35
# 1s - loss: 0.0118 - acc: 0.9962
# Epoch 33/35
# 1s - loss: 0.0111 - acc: 0.9960
# Epoch 34/35
# 1s - loss: 0.0111 - acc: 0.9968
# Epoch 35/35
# 1s - loss: 0.0121 - acc: 0.9958

# %%
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model3_history2 = model3.fit_generator(batch_generator(x_train3, y_train, 48),
                    verbose=2, epochs=5,
                    steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/5
# 1s - loss: 0.0050 - acc: 0.9987
# Epoch 2/5
# 1s - loss: 0.0148 - acc: 0.9947
# Epoch 3/5
# 1s - loss: 0.0120 - acc: 0.9971
# Epoch 4/5
# 1s - loss: 0.0079 - acc: 0.9971
# Epoch 5/5
# 1s - loss: 0.0047 - acc: 0.9985

# %%
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model3_history3 = model3.fit_generator(batch_generator(x_train3, y_train, 48),
                    verbose=2, epochs=5,
                    steps_per_epoch=x_train.shape[1]//32)
# Out:
# Epoch 1/5
# 1s - loss: 0.0136 - acc: 0.9958
# Epoch 2/5
# 1s - loss: 0.0065 - acc: 0.9985
# Epoch 3/5
# 1s - loss: 0.0088 - acc: 0.9973
# Epoch 4/5
# 1s - loss: 0.0126 - acc: 0.9968
# Epoch 5/5
# 1s - loss: 0.0056 - acc: 0.9983

# %%
# plotting validation loss and accuracy
plt.figure(figsize=(10,6))
plt.plot(model1_history.history['loss'], color='r', label="Model 1 Training loss")
plt.plot(model2_history.history['loss'], color='g', label="Model 2 Training loss")
plt.plot(model3_history.history['loss'], color='b', label="Model 3 Training loss")
plt.legend()
plt.show()


plt.figure(figsize=(10,6))
plt.plot(model1_history.history['acc'], color='r', label="Model 1 Training accuracy")
plt.plot(model2_history.history['acc'], color='g', label="Model 2 Training accuracy")
plt.plot(model3_history.history['acc'], color='b', label="Model 3 Training accuracy")
plt.legend()
plt.show()

# %%
# obtaining the indexes of yes-exoplanet and no-exoplanet
no_exoplanet = np.where(y_train[:,0] == 0.)[0]
yes_exoplanet = np.where(y_train[:,0] == 1.)[0]

# %%
y_pred1 = model1.predict(x_train1)[:,0]
y_final1 = model1.predict(x_final1)[:,0]

y_pred2 = model2.predict(x_train2)[:,0]
y_final2 = model2.predict(x_final2)[:,0]

y_pred3 = model3.predict(x_train3)[:,0]
y_final3 = model3.predict(x_final3)[:,0]

y_ensemble = (y_pred1 + y_pred2 + y_pred3)/3
y_ensemble_final = (y_final1 + y_final2 + y_final3)/3

# %%
# plots indicating the model allotting different range of scores for different classes
# thus imploying the precision of the model
plt.figure(figsize=(10,6))
plt.plot([y_pred1[i] for i in yes_exoplanet], 'ro', label="Model1-Exoplanet")
plt.plot([y_pred2[i] for i in yes_exoplanet], 'go', label="Model2-Exoplanet")
plt.plot([y_pred3[i] for i in yes_exoplanet], 'bo', label="Model3-Exoplanet")
plt.plot([y_ensemble[i] for i in yes_exoplanet], 'mo', label="Ensemble-Exoplanet")
plt.legend()
plt.show()

plt.figure(figsize=(10,6))
plt.plot([y_pred1[i] for i in no_exoplanet], 'ro', label="Model1-Non-exoplanet")
plt.plot([y_pred2[i] for i in no_exoplanet], 'go', label="Model2-Non-exoplanet")
plt.plot([y_pred3[i] for i in no_exoplanet], 'bo', label="Model3-Non-exoplanet")
plt.plot([y_ensemble[i] for i in no_exoplanet], 'mo', label="Ensemble-Exoplanet")
plt.legend()
plt.show()

# %%
y_true = (y_train[:, 0] + 0.5).astype("int")
f1_score_= []
skill_score_= []

for i in (np.arange(0.5,1.0,.005)):
    y_pred_int= np.copy(y_pred1)
    y_pred_int[(y_pred_int>i)]=1
    y_pred_int[(y_pred_int<=i)]=0

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_int).ravel()

    skill_score_.append(((tp * tn) - (fp * fn)) / ((tp + fn) * (fp + tn)))
    f1_score_.append(f1_score(y_true, y_pred_int, average='macro'))



print("F1 score : ", np.max(f1_score_))
print("Threshold for F1 score : ", (np.min(np.where(f1_score_ == np.max(f1_score_)))+1)*0.005+0.5)
print("*"*40)
print("True skill score : ", np.max(skill_score_))
print("Threshold for True skill score : ", (np.min(np.where(skill_score_ == np.max(skill_score_)))+1)*0.005+0.5)

plt.figure(figsize=(10,6))
plt.plot(f1_score_, color='b', label="F1 score")
plt.plot(skill_score_, color='r', label="True skill score")
plt.legend()
plt.show()
# Out:
# F1 score :  1.0
# Threshold for F1 score :  0.89
# ****************************************
# True skill score :  1.0
# Threshold for True skill score :  0.89

# %%
y_true = (y_train[:, 0] + 0.5).astype("int")
f1_score_= []
skill_score_= []

for i in (np.arange(0.5,1.0,.005)):
    y_pred_int= np.copy(y_pred2)
    y_pred_int[(y_pred_int>i)]=1
    y_pred_int[(y_pred_int<=i)]=0

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_int).ravel()

    skill_score_.append(((tp * tn) - (fp * fn)) / ((tp + fn) * (fp + tn)))
    f1_score_.append(f1_score(y_true, y_pred_int, average='macro'))



print("F1 score : ", np.max(f1_score_))
print("Threshold for F1 score : ", (np.min(np.where(f1_score_ == np.max(f1_score_)))+1)*0.005+0.5)
print("*"*40)
print("True skill score : ", np.max(skill_score_))
print("Threshold for True skill score : ", (np.min(np.where(skill_score_ == np.max(skill_score_)))+1)*0.005+0.5)

plt.figure(figsize=(10,6))
plt.plot(f1_score_, color='b', label="F1 score")
plt.plot(skill_score_, color='r', label="True skill score")
plt.legend()
plt.show()
# Out:
# F1 score :  1.0
# Threshold for F1 score :  0.895
# ****************************************
# True skill score :  1.0
# Threshold for True skill score :  0.895

# %%
y_true = (y_train[:, 0] + 0.5).astype("int")
f1_score_= []
skill_score_= []

for i in (np.arange(0.5,1.0,.005)):
    y_pred_int= np.copy(y_pred3)
    y_pred_int[(y_pred_int>i)]=1
    y_pred_int[(y_pred_int<=i)]=0

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_int).ravel()

    skill_score_.append(((tp * tn) - (fp * fn)) / ((tp + fn) * (fp + tn)))
    f1_score_.append(f1_score(y_true, y_pred_int, average='macro'))



print("F1 score : ", np.max(f1_score_))
print("Threshold for F1 score : ", (np.min(np.where(f1_score_ == np.max(f1_score_)))+1)*0.005+0.5)
print("*"*40)
print("True skill score : ", np.max(skill_score_))
print("Threshold for True skill score : ", (np.min(np.where(skill_score_ == np.max(skill_score_)))+1)*0.005+0.5)

plt.figure(figsize=(10,6))
plt.plot(f1_score_, color='b', label="F1 score")
plt.plot(skill_score_, color='r', label="True skill score")
plt.legend()
plt.show()
# Out:
# F1 score :  1.0
# Threshold for F1 score :  0.985
# ****************************************
# True skill score :  1.0
# Threshold for True skill score :  0.985

# %%
y_true = (y_train[:, 0] + 0.5).astype("int")
f1_score_= []
skill_score_= []

for i in (np.arange(0.5,1.0,.005)):
    y_ensemble_int= np.copy(y_ensemble)
    y_ensemble_int[(y_pred_int>i)]=1
    y_ensemble_int[(y_pred_int<=i)]=0

    tn, fp, fn, tp = confusion_matrix(y_true, y_ensemble_int).ravel()

    skill_score_.append(((tp * tn) - (fp * fn)) / ((tp + fn) * (fp + tn)))
    f1_score_.append(f1_score(y_true, y_ensemble_int, average='macro'))



print("F1 score : ", np.max(f1_score_))
print("Threshold for F1 score : ", (np.min(np.where(f1_score_ == np.max(f1_score_)))+1)*0.005+0.5)
print("*"*40)
print("True skill score : ", np.max(skill_score_))
print("Threshold for True skill score : ", (np.min(np.where(skill_score_ == np.max(skill_score_)))+1)*0.005+0.5)

plt.figure(figsize=(10,6))
plt.plot(f1_score_, color='b', label="F1 score")
plt.plot(skill_score_, color='r', label="True skill score")
plt.legend()
plt.show()
# Out:
# F1 score :  0.958698286813
# Threshold for F1 score :  0.505
# ****************************************
# True skill score :  0.848484848485
# Threshold for True skill score :  0.505

# %%
plt.figure(figsize=(10,6))
plt.plot(y_final1, 'ro', label="Model 1 prediction")
plt.plot(y_final2, 'go', label="Model 2 prediction")
plt.plot(y_final3, 'bo', label="Model 3 prediction")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(y_ensemble_final, 'bo', label="Model 3 prediction")
plt.legend()
plt.show()

# %%
len(y_ensemble_final[y_ensemble_final > 0.95])
# Out:
# 13

# %%
for i in range(len(y_ensemble_final)):
    if y_ensemble_final[i]>0.95: # this value is obtained from the above plot
        y_ensemble_final[i] = 1
    else:
        y_ensemble_final[i] = 0

# %%
label = y_ensemble_final+1

# %%
label = pd.DataFrame(label)

# %%
label.columns = ['LABEL']

# %%
label.to_csv('submission.csv', index=False)
